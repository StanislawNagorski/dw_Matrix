# %%
print("Hello! I lovve Werka! Kodowanie z zonką very cool :)")
# Out:
# Hello! I lovvvvve Werka! Kodowanie z zonką very cool :)

# %%
print("One small step for coding but big for our apartment!")
# Out:
# One small step for coding but big for our apartment!
